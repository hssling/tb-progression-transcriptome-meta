# %% [markdown]
# # TB Progression Transcriptome Meta Pipeline\nThis notebook runs end-to-end discovery/download/preprocess/analyze/manuscript generation.

# %%
# !python -m pip install --upgrade pip\n!python -m pip install -e .[dev]

# %%
# !tbmeta all --config configs/config.yaml --force

# %%
import pandas as pd\npd.read_csv('results/tables/loco_performance.csv')
